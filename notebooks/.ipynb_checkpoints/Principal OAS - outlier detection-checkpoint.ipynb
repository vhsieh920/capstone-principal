# %%
from datetime import datetime, timedelta, date
import csv
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import roc_auc_score, recall_score, precision_score
#roc_auc_score(y_true, y_scores)

# %% [markdown]
# ### Reading in the data & convert date to datetime object

# %%
file_name = '../Full_Monthly.csv'

# %%
def get_data(file):
    df = pd.read_csv(file, index_col = 0)
    df['Date'] = pd.to_datetime(df['Date'])
    return df

# %%
df = get_data(file_name)

# %%
df.head()
# Out:
#         Date Ticker                  Sector             Industry  \
# 1 1998-07-01    BAX  Consumer, Non-cyclical  Healthcare-Products
# 2 1998-07-01    VOD          Communications   Telecommunications
# 3 1998-07-01    PXD                  Energy              Oil&Gas
# 4 1998-07-01    KMI                  Energy            Pipelines
# 5 1998-07-01    AZN  Consumer, Non-cyclical      Pharmaceuticals
#
#    Cash From Operations  Current Market Cap  EBITDA Margin  Free Cash Flow  \
# 1               146.000          15118.3532        25.5814          17.000
# 2                   NaN         256921.1418            NaN             NaN
# 3                91.369           2398.8883        45.2357         -56.929
# 4               453.000          36519.0472        27.3650         -10.000
# 5               311.000          82119.0000        28.0482        -203.000
#
#    Gross Margin  Interest Expense   ...     Yield.10.Yr.Vol.63  \
# 1       46.0888            39.000   ...               0.100107
# 2           NaN               NaN   ...               0.100107
# 3       23.5375            41.017   ...               0.100107
# 4       34.1947           297.000   ...               0.100107
# 5       69.4947            33.000   ...               0.100107
#
#    Yield.20.Yr.Vol.21  Yield.20.Yr.Vol.63  Yield.30.Yr.Vol.21  \
# 1            0.067771            0.117695             0.06957
# 2            0.067771            0.117695             0.06957
# 3            0.067771            0.117695             0.06957
# 4            0.067771            0.117695             0.06957
# 5            0.067771            0.117695             0.06957
#
#    Yield.30.Yr.Vol.63     Total         OAS  Shiller.PE.Ratio  VIX.Value  \
# 1            0.126968  76.83215   72.402903             38.26  24.799999
# 2            0.126968  76.83215   78.340585             38.26  24.799999
# 3            0.126968  76.83215  147.188061             38.26  24.799999
# 4            0.126968  76.83215  113.533557             38.26  24.799999
# 5            0.126968  76.83215   60.176544             38.26  24.799999
#
#    VIX.VXV
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
#
# [5 rows x 81 columns]

# %% [markdown]
# ### To stay consistent, the tickers will we focus on are RTN, DE, and PG

# %%
df_pg = df[df.Ticker == 'PG']
df_pg.head()
# Out:
#           Date Ticker                  Sector                 Industry  \
# 95  1998-07-01     PG  Consumer, Non-cyclical  Cosmetics/Personal Care
# 205 1998-08-01     PG  Consumer, Non-cyclical  Cosmetics/Personal Care
# 327 1998-09-01     PG  Consumer, Non-cyclical  Cosmetics/Personal Care
# 462 1998-10-01     PG  Consumer, Non-cyclical  Cosmetics/Personal Care
# 541 1998-11-01     PG  Consumer, Non-cyclical  Cosmetics/Personal Care
#
#      Cash From Operations  Current Market Cap  EBITDA Margin  Free Cash Flow  \
# 95            1585.000000       122142.135700      16.567900      688.000000
# 205           1483.840889       108794.405880      19.692273      796.989102
# 327           1361.314649        98696.973968      22.301042      841.120122
# 462           1196.054153        95100.137871      23.878604      755.534982
# 541            986.337246       100017.218606      24.109228      511.630336
#
#      Gross Margin  Interest Expense   ...     Yield.10.Yr.Vol.63  \
# 95      42.804800        152.000000   ...               0.100107
# 205     43.908357        153.224175   ...               0.096231
# 327     44.857757        154.763327   ...               0.102958
# 462     45.498844        156.932432   ...               0.313982
# 541     45.756897        159.888808   ...               0.374456
#
#      Yield.20.Yr.Vol.21  Yield.20.Yr.Vol.63  Yield.30.Yr.Vol.21  \
# 95             0.067771            0.117695            0.069570
# 205            0.055283            0.115589            0.055848
# 327            0.085732            0.091965            0.108142
# 462            0.078516            0.187200            0.092554
# 541            0.168363            0.194161            0.134962
#
#      Yield.30.Yr.Vol.63       Total        OAS  Shiller.PE.Ratio  VIX.Value  \
# 95             0.126968   76.832150  52.293873             38.26  24.799999
# 205            0.125602   83.081350  56.404484             35.42  44.279999
# 327            0.104934  117.118731  81.900132             33.53  40.950001
# 462            0.218705  108.267015  76.465481             33.77  28.049999
# 541            0.247209  137.672554  78.197225             37.37  26.010000
#
#      VIX.VXV
# 95       NaN
# 205      NaN
# 327      NaN
# 462      NaN
# 541      NaN
#
# [5 rows x 81 columns]

# %%
def add_oas_columns(df):
    """Takes a dataframe indexed by date and adds 3 additional columns related to OAS"""
    df['oas_pct_change'] = df.OAS.pct_change()
    df = df.drop(df.index[0]) #drop the first row since pct change makes first value NaN
    df['outlier'] = np.where((df.oas_pct_change > np.mean(df.oas_pct_change) + np.std(df.oas_pct_change))|(df.oas_pct_change < np.mean(df.oas_pct_change) - np.std(df.oas_pct_change)),1,0)
    #df['oas_rank'] = pd.cut(df.oas_pct_change, bins = num_of_bins,labels = list(range(num_of_bins)))
    #df['outlier'] = np.where((df.oas_rank == 0)|(df.oas_rank == num_of_bins-1),1,0)
    return df

# %%
df_PG = add_oas_columns(df_pg)
df_PG.head()
# Out:
# /Users/veronicahsieh/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           Date Ticker                  Sector                 Industry  \
# 205 1998-08-01     PG  Consumer, Non-cyclical  Cosmetics/Personal Care
# 327 1998-09-01     PG  Consumer, Non-cyclical  Cosmetics/Personal Care
# 462 1998-10-01     PG  Consumer, Non-cyclical  Cosmetics/Personal Care
# 541 1998-11-01     PG  Consumer, Non-cyclical  Cosmetics/Personal Care
# 634 1998-12-01     PG  Consumer, Non-cyclical  Cosmetics/Personal Care
#
#      Cash From Operations  Current Market Cap  EBITDA Margin  Free Cash Flow  \
# 205           1483.840889       108794.405880      19.692273      796.989102
# 327           1361.314649        98696.973968      22.301042      841.120122
# 462           1196.054153        95100.137871      23.878604      755.534982
# 541            986.337246       100017.218606      24.109228      511.630336
# 634            815.392254       110112.495792      23.541495      237.578677
#
#      Gross Margin  Interest Expense   ...     Yield.20.Yr.Vol.63  \
# 205     43.908357        153.224175   ...               0.115589
# 327     44.857757        154.763327   ...               0.091965
# 462     45.498844        156.932432   ...               0.187200
# 541     45.756897        159.888808   ...               0.194161
# 634     45.900699        163.108011   ...               0.132408
#
#      Yield.30.Yr.Vol.21  Yield.30.Yr.Vol.63       Total        OAS  \
# 205            0.055848            0.125602   83.081350  56.404484
# 327            0.108142            0.104934  117.118731  81.900132
# 462            0.092554            0.218705  108.267015  76.465481
# 541            0.134962            0.247209  137.672554  78.197225
# 634            0.072005            0.146521  117.358650  76.643962
#
#      Shiller.PE.Ratio  VIX.Value  VIX.VXV  oas_pct_change  outlier
# 205             35.42  44.279999      NaN        0.078606        0
# 327             33.53  40.950001      NaN        0.452015        1
# 462             33.77  28.049999      NaN       -0.066357        0
# 541             37.37  26.010000      NaN        0.022647        0
# 634             38.82  24.420000      NaN       -0.019863        0
#
# [5 rows x 83 columns]

# %%
features = ['Date','Current Market Cap','Shares.Outstanding','Gross Margin','Interest Expense','Cash From Operations','EBITDA Margin','Net Debt','Total Current Liabilities','Total Assets','Revenue','Long Term Debt','Stock.Price','Net Income/Net Profit (Losses)','Short and Long Term Debt','Free Cash Flow']

# %%
def create_model_data(features_list,df):
    """Lags all the features by 1 month and merges it back to the outlier column"""
    df_features = df[features]
    df_features['Date'] = df_features['Date'] + pd.DateOffset(months=1)
    df_y = df[['Date','outlier']]
    df_lagged = pd.merge(df_features,df_y,on = 'Date')
    return df_lagged

# %%
model_data = create_model_data(features,df_PG)
model_data.head()
# Out:
# /Users/veronicahsieh/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#         Date  Current Market Cap  Shares.Outstanding  Gross Margin  \
# 0 1998-09-01       108794.405880              2682.6     43.908357
# 1 1998-10-01        98696.973968              2682.6     44.857757
# 2 1998-11-01        95100.137871              2674.8     45.498844
# 3 1998-12-01       100017.218606              2674.8     45.756897
# 4 1999-01-01       110112.495792              2651.8     45.900699
#
#    Interest Expense  Cash From Operations  EBITDA Margin     Net Debt  \
# 0        153.224175           1483.840889      19.692273  5888.137838
# 1        154.763327           1361.314649      22.301042  6117.348401
# 2        156.932432           1196.054153      23.878604  6308.704413
# 3        159.888808            986.337246      24.109228  6447.128215
# 4        163.108011            815.392254      23.541495  6534.188979
#
#    Total Current Liabilities  Total Assets      Revenue  Long Term Debt  \
# 0                9757.182639  31720.566855  9310.013242     6003.047478
# 1               10188.100241  32382.683650  9375.383492     6209.170005
# 2               10466.487770  32859.900323  9505.467760     6351.442634
# 3               10541.330812  33091.135604  9709.092595     6409.598679
# 4               10470.805869  33150.955837  9893.332120     6413.785136
#
#    Stock.Price  Net Income/Net Profit (Losses)  Short and Long Term Debt  \
# 0     38.25000                      888.544664               8729.007668
# 1     35.56250                     1059.025956               9294.899648
# 2     44.34375                     1165.380505               9626.560254
# 3     43.81250                     1188.298315               9653.631664
# 4     45.65625                     1163.618627               9507.950427
#
#    Free Cash Flow  outlier
# 0      796.989102        1
# 1      841.120122        0
# 2      755.534982        0
# 3      511.630336        0
# 4      237.578677        0

# %%
test = model_data.iloc[176:232]

# %%
train = model_data.iloc[0:175]
train
# Out:
#           Date  Current Market Cap  Shares.Outstanding  Gross Margin  \
# 0   1998-09-01       108794.405880            2682.600     43.908357
# 1   1998-10-01        98696.973968            2682.600     44.857757
# 2   1998-11-01        95100.137871            2674.800     45.498844
# 3   1998-12-01       100017.218606            2674.800     45.756897
# 4   1999-01-01       110112.495792            2651.800     45.900699
# 5   1999-02-01       120604.706490            2651.800     46.291863
# 6   1999-03-01       127490.764539            2651.800     47.108023
# 7   1999-04-01       130406.225034            2652.800     47.666579
# 8   1999-05-01       130049.240052            2652.800     47.033715
# 9   1999-06-01       127200.242091            2657.000     44.638554
# 23       865.422096        0
# 24       701.335346        0
# 25       558.873785        0
# 26       465.712201        0
# 27       444.847115        0
# 28       481.849912        0
# 29       543.864926        0
# ..              ...      ...
# 145     1924.726114        0
# 146     1839.772021        0
# 147     1913.877883        0
# 148     1950.836247        0
# 149     1961.454197        0
# 150     2069.964371        0
# 151     2383.231881        0
# 152     2817.698650        0
# 153     3177.860147        0
# 154     3280.742706        0
# 155     3100.691888        0
# 156     2711.226543        1
# 157     2192.270061        0
# 158     1683.859725        0
# 159     1366.647486        1
# 160     1406.439233        0
# 161     1755.795192        0
# 162     2212.932040        0
# 163     2581.502336        0
# 164     2799.382475        0
# 165     2908.483061        1
# 166     2950.733471        0
# 167     2922.735243        0
# 168     2783.478353        0
# 169     2497.456804        0
# 170     2153.680674        0
# 171     1951.745316        0
# 172     2084.011347        0
# 173     2509.905887        0
# 174     2967.465427        0
#
# [175 rows x 17 columns]

# %%
train_X = train[['Current Market Cap', 'Shares.Outstanding', 'Gross Margin',
       'Interest Expense', 'Cash From Operations', 'EBITDA Margin',
       'Net Debt', 'Total Current Liabilities', 'Total Assets', 'Revenue',
       'Long Term Debt', 'Stock.Price', 'Net Income/Net Profit (Losses)',
       'Short and Long Term Debt', 'Free Cash Flow']]

# %%
test_X = test[['Current Market Cap', 'Shares.Outstanding', 'Gross Margin',
       'Interest Expense', 'Cash From Operations', 'EBITDA Margin',
       'Net Debt', 'Total Current Liabilities', 'Total Assets', 'Revenue',
       'Long Term Debt', 'Stock.Price', 'Net Income/Net Profit (Losses)',
       'Short and Long Term Debt', 'Free Cash Flow']]

# %%
train_Y = train[['outlier']]

# %%
test_Y = test[['outlier']]

# %%
clf = LogisticRegression(random_state=0, solver='lbfgs',multi_class='multinomial').fit(train_X, train_Y)
# Out:
# /Users/veronicahsieh/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
clf2 = LogisticRegressionCV(cv=10, random_state=0,multi_class='multinomial').fit(train_X, train_Y)
# Out:
# /Users/veronicahsieh/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
predicted_Y = clf.predict(test_X)

# %%
predicted_Y2 = clf2.predict(test_X)

# %%
def performance_metrics(actual,predicted):
    """Calculates the AUC, precision, and recall scores for the test set using sklearn metrics"""
    auc = roc_auc_score(actual, predicted)
    precision = list(precision_score(actual, predicted, average=None))
    recall = list(recall_score(actual, predicted,average =None))
    print("auc: {}".format(auc))
    print("precision: {}".format(precision))
    print("recall: {}".format(recall))
    return auc, precision, recall

# %%
test1 = performance_metrics(test_Y,predicted_Y2)
test1
# Out:
# auc: 0.5
# precision: [0.8928571428571429, 0.0]
# recall: [1.0, 0.0]
# /Users/veronicahsieh/miniconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# (0.5, [0.8928571428571429, 0.0], [1.0, 0.0])

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=4)
neigh.fit(train_X, train_Y)
# Out:
# /Users/veronicahsieh/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#            weights='uniform')

# %%
predicted_Y3 = neigh.predict(test_X)

# %%
neigh.score(train_X,train_Y)
# Out:
# 0.9085714285714286

# %%
test3 = performance_metrics(test_Y,predicted_Y3)
test3
# Out:
# auc: 0.5
# precision: [0.8928571428571429, 0.0]
# recall: [1.0, 0.0]
# /Users/veronicahsieh/miniconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# (0.5, [0.8928571428571429, 0.0], [1.0, 0.0])
