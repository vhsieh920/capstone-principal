# %%
import pandas as pd

# %%
data = pd.read_csv("Full_Monthly.csv")

# %%
data.head()
# Out:
#    Unnamed: 0        Date Ticker                  Sector             Industry  \
# 0           1  1998-07-01    BAX  Consumer, Non-cyclical  Healthcare-Products
# 1           2  1998-07-01    VOD          Communications   Telecommunications
# 2           3  1998-07-01    PXD                  Energy              Oil&Gas
# 3           4  1998-07-01    KMI                  Energy            Pipelines
# 4           5  1998-07-01    AZN  Consumer, Non-cyclical      Pharmaceuticals
#
#    Cash From Operations  Current Market Cap  EBITDA Margin  Free Cash Flow  \
# 0               146.000          15118.3532        25.5814          17.000
# 1                   NaN         256921.1418            NaN             NaN
# 2                91.369           2398.8883        45.2357         -56.929
# 3               453.000          36519.0472        27.3650         -10.000
# 4               311.000          82119.0000        28.0482        -203.000
#
#    Gross Margin   ...     Yield.10.Yr.Vol.63  Yield.20.Yr.Vol.21  \
# 0       46.0888   ...               0.100107            0.067771
# 1           NaN   ...               0.100107            0.067771
# 2       23.5375   ...               0.100107            0.067771
# 3       34.1947   ...               0.100107            0.067771
# 4       69.4947   ...               0.100107            0.067771
#
#    Yield.20.Yr.Vol.63  Yield.30.Yr.Vol.21  Yield.30.Yr.Vol.63     Total  \
# 0            0.117695             0.06957            0.126968  76.83215
# 1            0.117695             0.06957            0.126968  76.83215
# 2            0.117695             0.06957            0.126968  76.83215
# 3            0.117695             0.06957            0.126968  76.83215
# 4            0.117695             0.06957            0.126968  76.83215
#
#           OAS  Shiller.PE.Ratio  VIX.Value  VIX.VXV
# 0   72.402903             38.26  24.799999      NaN
# 1   78.340585             38.26  24.799999      NaN
# 2  147.188061             38.26  24.799999      NaN
# 3  113.533557             38.26  24.799999      NaN
# 4   60.176544             38.26  24.799999      NaN
#
# [5 rows x 82 columns]

# %%
data[data.Date == data.Date.min()].shape
# Out:
# (116, 82)

# %%
data[data.Date == data.Date.max()].shape
# Out:
# (210, 82)

# %%
cpi = pd.read_csv("Consumer_Price_Index_CPI.csv")

# %%
Date_list = list(data[data.Date > '2012-12-01'].Date.unique())

# %%
OAS = list(data[data.Date > '2012-12-01'].groupby("Date").agg({"OAS" : "mean"}).OAS)

# %%
CPI = list(cpi[cpi.DateTime >= '2013-01-01T00:00:00'][cpi.DateTime < '2018-01-01T00:00:00'].Value)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
gdp = pd.read_csv("GDP_Growth_Rate.csv")

# %%
gdp.head()
# Out:
#          Country         Category             DateTime  Value  Frequency  \
# 0  United States  GDP Growth Rate  1947-06-30T00:00:00   -1.0  Quarterly
# 1  United States  GDP Growth Rate  1947-09-30T00:00:00   -0.8  Quarterly
# 2  United States  GDP Growth Rate  1947-12-31T00:00:00    6.4  Quarterly
# 3  United States  GDP Growth Rate  1948-03-31T00:00:00    6.2  Quarterly
# 4  United States  GDP Growth Rate  1948-06-30T00:00:00    6.8  Quarterly
#
#   HistoricalDataSymbol           LastUpdate
# 0             GDP CQOQ  2018-07-27T13:11:00
# 1             GDP CQOQ  2018-07-27T13:11:00
# 2             GDP CQOQ  2014-07-30T14:08:00
# 3             GDP CQOQ  2018-07-27T13:11:00
# 4             GDP CQOQ  2018-07-27T13:11:00

# %%
gdp.DateTime = pd.to_datetime(gdp.DateTime)

# %%
gdp_series = pd.Series(list(gdp.Value), index=gdp.DateTime)

# %%
gdp_series = gdp_series.resample('M').pad()[5:]

# %%
GDP = list(gdp_series[ "2013-1-1":"2018-1-1"])

# %%
inflation = pd.read_csv("Inflation_Rate.csv")

# %%
INFLATION = list(inflation[inflation.DateTime >= '2013-01-01T00:00:00'][inflation.DateTime < '2018-01-01T00:00:00'].Value)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
interest = pd.read_csv("Interest_Rate.csv")

# %%
INTEREST = list(interest[interest.DateTime >= '2012-12-01T00:00:00'][interest.DateTime < '2018-01-01T00:00:00'].Value)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
unemployment = pd.read_csv("Unemployment_Rate.csv")

# %%
UNEMPLOYMENT = list(unemployment[unemployment.DateTime >= '2013-01-01T00:00:00'][unemployment.DateTime < '2018-01-01T00:00:00'].Value)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
external = pd.DataFrame(
    {'OAS': OAS,
     'GDP': GDP,
     "CPI":CPI,
     "Inflation":INFLATION,
     'Interest': INTEREST,
     'Unemployment':UNEMPLOYMENT,
    })

# %%
external = external.pct_change()

# %%
external.GDP = GDP

# %%
external['Date'] = Date_list

# %%
external
# Out:
#          CPI  GDP  Inflation  Interest       OAS  Unemployment        Date
# 0        NaN  0.5        NaN       NaN       NaN           NaN  2013-01-01
# 1   0.005430  0.5   0.250000  0.000000 -0.012216     -0.037500  2013-02-01
# 2  -0.002812  3.6  -0.250000  0.000000  0.000073     -0.025974  2013-03-01
# 3  -0.002088  3.6  -0.266667  0.000000  0.018004      0.013333  2013-04-01
# 4   0.000414  3.6   0.272727  0.000000 -0.021461     -0.013158  2013-05-01
# 5   0.002380  0.5   0.285714  0.000000 -0.012505      0.000000  2013-06-01
# 6   0.001957  0.5   0.111111  0.000000  0.132709     -0.026667  2013-07-01
# 7   0.002387  0.5  -0.250000  0.000000 -0.083746     -0.013699  2013-08-01
# 8   0.000377  3.2  -0.200000  0.000000  0.022102      0.000000  2013-09-01
# 9   0.000535  3.2  -0.166667  0.000000  0.024521      0.000000  2013-10-01
# 10  0.001844  3.2   0.200000  0.000000 -0.049136     -0.041667  2013-11-01
# 11  0.002644  3.2   0.250000  0.000000 -0.029087     -0.028986  2013-12-01
# 12  0.002676  3.2   0.066667  0.000000 -0.088311     -0.014925  2014-01-01
# 13  0.000744  3.2  -0.312500  0.000000 -0.004131      0.015152  2014-02-01
# 14  0.001843 -1.0   0.363636  0.000000 -0.049825      0.000000  2014-03-01
# 15  0.002149 -1.0   0.333333  0.000000 -0.049676     -0.059701  2014-04-01
# 16  0.001709 -1.0   0.050000  0.000000 -0.041154      0.000000  2014-05-01
# 17  0.001355  5.1   0.000000  0.000000  0.003666     -0.031746  2014-06-01
# 18  0.001252  5.1  -0.047619  0.000000 -0.011934      0.016393  2014-07-01
# 19 -0.000194  5.1  -0.150000  0.000000 -0.008896      0.000000  2014-08-01
# 20  0.000055  4.9   0.000000  0.000000  0.032018     -0.048387  2014-09-01
# 21 -0.000021  4.9   0.000000  0.000000  0.084457     -0.033898  2014-10-01
# 22 -0.001706  4.9  -0.235294  0.000000  0.060805      0.017544  2014-11-01
# 23 -0.003257  1.9  -0.384615  0.000000  0.059494     -0.034483  2014-12-01
# 24 -0.006069  1.9  -1.125000  0.000000  0.054860      0.017857  2015-01-01
# 25  0.001865  1.9  -1.000000  0.000000  0.036976     -0.035088  2015-02-01
# 26  0.002899  3.3       -inf  0.000000 -0.105264      0.000000  2015-03-01
# 27  0.000886  3.3   1.000000  0.000000  0.062474     -0.018182  2015-04-01
# 28  0.003332  3.3  -1.000000  0.000000 -0.023417      0.018519  2015-05-01
# 29  0.002811  3.3        inf  0.000000  0.053062     -0.036364  2015-06-01
# 30  0.001578  3.3   1.000000  0.000000  0.094802     -0.018868  2015-07-01
# 31 -0.000017  3.3   0.000000  0.000000  0.066535     -0.019231  2015-08-01
# 32 -0.002193  1.0  -1.000000  0.000000  0.072442     -0.019608  2015-09-01
# 33  0.001251  1.0        inf  0.000000  0.040290      0.000000  2015-10-01
# 34  0.001295  1.0   1.500000  0.000000 -0.065911      0.000000  2015-11-01
# 35 -0.001029  0.4   0.400000  1.000000  0.000610      0.000000  2015-12-01
# 36  0.000685  0.4   1.000000  0.000000  0.089555     -0.020000  2016-01-01
# 37 -0.001924  0.4  -0.285714  0.000000  0.150059      0.000000  2016-02-01
# 38  0.002063  1.5  -0.100000  0.000000 -0.038927      0.020408  2016-03-01
# 39  0.003449  1.5   0.222222  0.000000 -0.164937      0.000000  2016-04-01
# 40  0.002495  1.5  -0.090909  0.000000 -0.112447     -0.060000  2016-05-01
# 41  0.002652  2.3   0.000000  0.000000  0.017649      0.042553  2016-06-01
# 42 -0.000067  2.3  -0.200000  0.000000  0.045251      0.000000  2016-07-01
# 43  0.002129  2.3   0.375000  0.000000 -0.070461      0.000000  2016-08-01
# 44  0.001862  1.9   0.363636  0.000000 -0.065287      0.020408  2016-09-01
# 45  0.002697  1.9   0.066667  0.000000  0.014253     -0.020000  2016-10-01
# 46  0.001713  1.9   0.062500  0.000000 -0.040865     -0.061224  2016-11-01
# 47  0.002904  1.8   0.235294  0.500000 -0.022413      0.021739  2016-12-01
# 48  0.005124  1.8   0.190476  0.000000 -0.042016      0.021277  2017-01-01
# 49  0.000303  1.8   0.080000  0.000000 -0.023888     -0.020833  2017-02-01
# 50 -0.001577  1.8  -0.111111  0.333333 -0.041771     -0.042553  2017-03-01
# 51  0.001518  1.8  -0.083333  0.000000  0.022305     -0.022222  2017-04-01
# 52 -0.000721  1.8  -0.136364  0.000000 -0.018184     -0.022727  2017-05-01
# 53  0.000496  3.0  -0.157895  0.250000 -0.027536      0.000000  2017-06-01
# 54  0.000836  3.0   0.062500  0.000000 -0.033164      0.000000  2017-07-01
# 55  0.004201  3.0   0.117647  0.000000 -0.063579      0.023256  2017-08-01
# 56  0.004607  2.8   0.157895  0.000000  0.087252     -0.045455  2017-09-01
# 57  0.000775  2.8  -0.090909  0.000000 -0.069985     -0.023810  2017-10-01
# 58  0.003358  2.8   0.100000  0.000000 -0.065608      0.000000  2017-11-01
# 59  0.002017  2.3  -0.045455  0.200000  0.021073      0.000000  2017-12-01

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

% matplotlib inline

sns.set(style="white")

# Compute the correlation matrix
corr = external[1:].drop(['Date'], axis=1).corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
import seaborn as sns; sns.set()

# %%
external.set_index("Date")
import matplotlib.pyplot as plt
fmri = sns.load_dataset("fmri")

external.plot()
